# %%
import numpy as np
import math
import os
import matplotlib.pyplot as plt
from spinnorse_tools import plot_all_spike_trains, generate_trains

# %%
path = "../experiments"
experiments=os.listdir(path)
for e in experiments:
#     if e == "single_neuron":
#         generate_trains(path+"/"+e+"/input", 200, 20, 80, 16)
#         plot_all_spike_trains(path+"/"+e+"/input")
#     if e == "pathway_1d":
#         generate_trains(path+"/"+e+"/input", 200, 20, 80, 16)
#         plot_all_spike_trains(path+"/"+e+"/input")
    if e == "funnel":
        generate_trains(path+"/"+e+"/input", 400, 10, 120, 16)
        plot_all_spike_trains(path+"/"+e+"/input")
