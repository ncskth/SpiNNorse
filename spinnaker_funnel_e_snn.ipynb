# %%
import socket
import spynnaker8 as sp8
from pyNN.random import NumpyRNG, RandomDistribution
from pyNN.utility.plotting import Figure, Panel
import matplotlib.pyplot as plt
import pdb
import numpy as np
from numpy import genfromtxt
from spinnorse_tools import fetch_files, plot_iho
import os
import time
# Out:
# Detected PyNN version 0.9.4 and Neo version 0.6.1

# %%
dt = 1           # (ms) simulation timestep

cell_params = {'tau_m': 20.0,
               'tau_syn_E': 5.0,
               'tau_syn_I': 5.0,
               'v_rest': -65.0,
               'v_reset': -65.0,
               'v_thresh': -50.0,
               'tau_refrac': 0.0, # 0.1 originally
               'cm': 1,
               'i_offset': 0.0
               }

w_ih = 0.02
w_ho = 1

# %%
#SpiNNaker Setup
delay = 2*dt
nb_steps = 200
node_id = sp8.setup(timestep=dt, min_delay=delay, max_delay=delay)     
celltype = sp8.IF_curr_exp
sp8.set_number_of_neurons_per_core(celltype, 10) #  100 neurons per core

nb_hl = 1
ratio = 4
nb_nol = 1
nb_nhl = nb_nol*(ratio**(nb_hl))
nb_nil = nb_nol*(ratio**(nb_hl+1))

# Fetch available trains of spikes in path
path = "summary/common/"
files = fetch_files(path)

# Stack Spike Trains
spike_trains = np.zeros((nb_steps,nb_nil))
for i in range(nb_nil):
    try:
        spike_trains[:,i] = genfromtxt(files[i], delimiter=',')
    except:
        print("spikes_%02d.csv not available " % (i+1))
# Out:
# 2020-12-24 12:22:26 INFO: Read cfg files: /home/jprb/myspin/lib/python3.6/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/jprb/myspin/lib/python3.6/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/jprb/.spynnaker.cfg
# 2020-12-24 12:22:26 INFO: Will search these locations for binaries: /home/jprb/myspin/lib/python3.6/site-packages/spinn_front_end_common/common_model_binaries : /home/jprb/myspin/lib/python3.6/site-packages/spynnaker/pyNN/model_binaries
# 2020-12-24 12:22:26 WARNING: /home/jprb/SpiNNorse/reports has 31 old reports that have not been closed
# 2020-12-24 12:22:26 WARNING: /home/jprb/SpiNNorse/application_generated_data_files has 31 old reports that have not been closed
# 2020-12-24 12:22:26 INFO: Setting time scale factor to 1.
# 2020-12-24 12:22:26 INFO: Setting machine time step to 1000 micro-seconds.
# ['/home/jprb/myspin/lib/python3.6/site-packages/spinn_front_end_common/interface/spinnaker.cfg', '/home/jprb/myspin/lib/python3.6/site-packages/spynnaker/pyNN/spynnaker.cfg', '/home/jprb/.spynnaker.cfg']

# %%
# Create Populations

fcnn_i = []
for i in range(nb_nil):
    i_indexes = np.asarray(np.where(spike_trains[:,i]>0)).reshape(-1)
    fcnn_i.append(sp8.Population(nb_nil,sp8.SpikeSourceArray(spike_times=(i_indexes))))

fcnn_h = []
for i in range(nb_nhl):
    pop_name = "fcnn_h_" + str(i)
    fcnn_h.append(sp8.Population(1, celltype(**cell_params), label=pop_name))

fcnn_o = []
for i in range(nb_nol):
    pop_name = "fcnn_o_" + str(i)
    fcnn_o.append(sp8.Population(1, celltype(**cell_params), label=pop_name))

# %%
# Setup Connectivity
con = sp8.AllToAllConnector()

syn = sp8.StaticSynapse(weight=w_ih, delay=0)
for i in range(nb_nil):
    print("fcnn_i[%d] --> fcnn_h[%d]" % (i, int(i/ratio)))
    sp8.Projection(fcnn_i[i], fcnn_h[int(i/ratio)], con, receptor_type='excitatory', synapse_type=syn)

syn = sp8.StaticSynapse(weight=w_ho, delay=0)    
for i in range(nb_nhl):
    print("fcnn_h[%d] --> fcnn_o[%d]" % (i, int(i/ratio)))
    sp8.Projection(fcnn_h[i], fcnn_o[int(i/ratio)], con, receptor_type='excitatory', synapse_type=syn)

# Record Voltages and Spikes
for i in range(nb_nil):
    fcnn_i[i].record(["spikes"])
for i in range(nb_nhl):
    fcnn_h[i].record(["v","spikes"])
for i in range(nb_nol):
    fcnn_o[i].record(["v","spikes"])
# Out:
# fcnn_i[0] --> fcnn_h[0]
# fcnn_i[1] --> fcnn_h[0]
# fcnn_i[2] --> fcnn_h[0]
# fcnn_i[3] --> fcnn_h[0]
# fcnn_i[4] --> fcnn_h[1]
# fcnn_i[5] --> fcnn_h[1]
# fcnn_i[6] --> fcnn_h[1]
# fcnn_i[7] --> fcnn_h[1]
# fcnn_i[8] --> fcnn_h[2]
# fcnn_i[9] --> fcnn_h[2]
# fcnn_i[10] --> fcnn_h[2]
# fcnn_i[11] --> fcnn_h[2]
# fcnn_i[12] --> fcnn_h[3]
# fcnn_i[13] --> fcnn_h[3]
# fcnn_i[14] --> fcnn_h[3]
# fcnn_i[15] --> fcnn_h[3]
# fcnn_h[0] --> fcnn_o[0]
# fcnn_h[1] --> fcnn_o[0]
# fcnn_h[2] --> fcnn_o[0]
# fcnn_h[3] --> fcnn_o[0]

# %%
# Start Simulation
sp8.run(nb_steps)

# Get recorded data
i_spikes = np.zeros((nb_steps,nb_nil))
for i in range(nb_nil):
    indexes = np.asarray(fcnn_i[i].get_data("spikes").segments[0].spiketrains[0]).astype(int).reshape(-1)
    np.put(i_spikes[:,i],indexes, np.ones(indexes.shape[0]))
    
o_spikes_hl = np.zeros((nb_steps,nb_nhl))
v_hl = np.zeros((nb_steps,nb_nhl))
for i in range(nb_nhl):
    indexes = np.asarray(fcnn_h[i].get_data("spikes").segments[0].spiketrains[0]).astype(int).reshape(-1)
    np.put(o_spikes_hl[:,i],indexes, np.ones(indexes.shape[0]))
    v_hl[:,i] = np.asarray(fcnn_h[i].get_data("v").segments[0].filter(name="v")[0]).reshape(-1)
    
o_spikes_ol = np.zeros((nb_steps,nb_nol))
v_ol = np.zeros((nb_steps,nb_nol))
for i in range(nb_nol):
    indexes = np.asarray(fcnn_o[i].get_data("spikes").segments[0].spiketrains[0]).astype(int).reshape(-1)
    np.put(o_spikes_ol[:,i],indexes, np.ones(indexes.shape[0]))
    v_ol[:,i] = np.asarray(fcnn_o[i].get_data("v").segments[0].filter(name="v")[0]).reshape(-1)
    
# End Simulation
sp8.end()
# Out:
# 2020-12-24 12:22:26 INFO: Simulating for 200 1.0ms timesteps using a hardware timestep of 1000us
# 2020-12-24 12:22:26 INFO: Starting execution process
# 2020-12-24 12:22:26 INFO: Creating transceiver for 192.168.240.1
# 2020-12-24 12:22:26 INFO: Working out if machine is booted
# 2020-12-24 12:22:26 INFO: Found board with version [Version: SC&MP 3.2.5 at SpiNNaker:0:0:0 (built Thu Aug  1 10:15:06 2019)]
# 2020-12-24 12:22:26 INFO: Machine communication successful
# 2020-12-24 12:22:26 INFO: Detected a machine on IP address 192.168.240.1 which has 858 cores and 120.0 links
# 2020-12-24 12:22:26 INFO: Time 0:00:00.012421 taken by MachineGenerator
# Pre allocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.022151 taken by PreAllocateResourcesForExtraMonitorSupport
# 2020-12-24 12:22:26 INFO: Time 0:00:00.000382 taken by NetworkSpecificationReport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.032946 taken by PartitionAndPlacePartitioner
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.013549 taken by PartitionerReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.036721 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.032953 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.006066 taken by BoardChipReport
# Filtering edges
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.046285 taken by GraphEdgeFilter
# Placing graph vertices
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.038994 taken by OneToOnePlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.046317 taken by InsertEdgesToExtraMonitorFunctionality
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.006975 taken by DataInMulticastRoutingGenerator
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.006161 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:26 INFO: Time 0:00:00.052586 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
#
# 2020-12-24 12:22:26 INFO: Time 0:00:00.029523 taken by NerRoute
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.042935 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.004817 taken by TagReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.030983 taken by EdgeToNKeysMapper
# Getting constraints for application graph
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.029274 taken by ProcessPartitionConstraints
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.019768 taken by MallocBasedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.030575 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.027016 taken by BasicRoutingTableGenerator
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.063147 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.037645 taken by BufferManagerCreator
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.102035 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.009284 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:27 INFO: Time 0:00:00.040112 taken by GraphBinaryGatherer
# Running routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:31 INFO: Time 0:00:04.514997 taken by MundyOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:31 INFO: Time 0:00:00.008064 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:32 INFO: Time 0:00:00.032082 taken by LoadFixedRoutes
# Executing data specifications and loading data for system vertices
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:32 INFO: Time 0:00:00.128448 taken by HostExecuteSystemDataSpecification
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:37 INFO: Time 0:00:05.714028 taken by LoadSystemExecutableImages
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:37 INFO: Time 0:00:00.015005 taken by TagsLoader
# Writing data
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:37 INFO: Time 0:00:00.029452 taken by WriteMemoryIOData
# Executing data specifications and loading data for application vertices
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:38 INFO: Time 0:00:00.158618 taken by HostExecuteApplicationDataSpecification
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:41 INFO: Time 0:00:03.765153 taken by SynapseExpander
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:41 INFO: Time 0:00:00.032345 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:48 INFO: Time 0:00:06.753233 taken by LoadApplicationExecutableImages
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:48 INFO: Time 0:00:00.025025 taken by RoutingTableFromMachineReport
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:48 INFO: Time 0:00:00.010020 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:48 INFO: Time 0:00:00.006601 taken by comparisonOfRoutingTablesReport
# 2020-12-24 12:22:48 INFO: Running for 1 steps for a total of 200.0ms
# 2020-12-24 12:22:48 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:48 INFO: Time 0:00:00.055189 taken by SdramUsageReportPerChip
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:48 INFO: Time 0:00:00.042765 taken by ChipRuntimeUpdater
# 2020-12-24 12:22:48 INFO: Time 0:00:00.000187 taken by DatabaseInterface
# 2020-12-24 12:22:48 INFO: ** Notifying external sources that the database is ready for reading **
# 2020-12-24 12:22:48 INFO: Time 0:00:00.000741 taken by NotificationProtocol
# 2020-12-24 12:22:48 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:49 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2020-12-24 12:22:49 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2020-12-24 12:22:49 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2020-12-24 12:22:49 INFO: Application started; waiting 0.30000000000000004s for it to stop
# 2020-12-24 12:22:50 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2020-12-24 12:22:50 INFO: Time 0:00:01.510086 taken by ApplicationRunner
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:50 INFO: Time 0:00:00.164508 taken by BufferExtractor
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:50 INFO: Time 0:00:00.077506 taken by GraphProvenanceGatherer
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:50 INFO: Time 0:00:00.036065 taken by PlacementsProvenanceGatherer
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:50 INFO: Time 0:00:00.047245 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:50 INFO: Time 0:00:00.031239 taken by ProfileDataGatherer
# Getting spikes for SpikeSourceArrayVertex_1
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_2
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_3
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_4
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_5
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_6
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_7
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_8
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_9
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_10
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_11
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_12
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_13
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_14
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_15
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for SpikeSourceArrayVertex_16
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for fcnn_h_0
# |0%                          50%                         100%|
#  ============================================================
# Getting v for fcnn_h_0
# |0%                          50%                         100%|
#  ============================================================
# 2020-12-24 12:22:50 WARNING: Warning getting data on a whole population when selective recording is active will result in only the requested neurons being returned in numerical order and without repeats.
# Getting spikes for fcnn_h_1
# |0%                          50%                         100%|
#  ============================================================
# Getting v for fcnn_h_1
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for fcnn_h_2
# |0%                          50%                         100%|
#  ============================================================
# Getting v for fcnn_h_2
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for fcnn_h_3
# |0%                          50%                         100%|
#  ============================================================
# Getting v for fcnn_h_3
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for fcnn_o_0
# |0%                          50%                         100%|
#  ============================================================
# Getting v for fcnn_o_0
# |0%                          50%                         100%|
#  ============================================================

# %%
# Plot Stuff
sfn = "My Test"
plot_iho(i_spikes, o_spikes_hl, v_hl, o_spikes_ol, v_ol, sfn, nb_steps, ratio)

# %%
# max(v_hl[0:nb_steps,:])

# %%
# max(v_ol[0:nb_steps,:])
